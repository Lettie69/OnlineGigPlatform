# %% [markdown]
# # 此代码实现基于Data数据的逻辑回归

# %%
import pandas as pd
data = pd.read_excel("data.xlsx")

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = data.copy()
# Converting all columns except 'bid', 'pid', 'solverid', and 'description' to numeric
columns_to_convert = df.columns.difference(['bid', 'pid', 'solverid', 'description'])

# Applying conversion to numeric, with errors='coerce' to handle non-numeric values
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# Checking for any non-numeric values that were converted to NaN
null_values = df[columns_to_convert].isnull().sum()

# %%
# Specify the columns to drop
columns_to_drop = ['bid', 'pid', 'solverid', 'description', 'price', 'seekerid', 'time_diff']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62129 entries, 0 to 62128
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DDelivery                   62129 non-null  int64
#  1   competition                 62129 non-null  int64
#  2   std_award_status            62129 non-null  int64
#  3   std_price                   62129 non-null  float64
#  4   word                        62129 non-null  int64
#  5   confidence_prediction       62129 non-null  int64
#  6   skill_prediction            62129 non-null  int64
#  7   standardization_prediction  62129 non-null  int64
#  8   experience_prediction       62129 non-null  int64
#  9   politeness_prediction       62129 non-null  int64
#  10  customization_prediction    62129 non-null  int64
#  11  time_diff_dummy             62129 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 5.7 MB

# %%
df.sample(4)
# Out:
#        DDelivery  competition  std_award_status    std_price  word  \
# 57639          7           87                 0  15000.00000   120
# 43426         40           67                 0   1500.00000    24
# 31306          7           20                 0   1125.00000    92
# 33541          7           42                 0     15.44175   163
#
#        confidence_prediction  skill_prediction  standardization_prediction  \
# 57639                      1                 1                           1
# 43426                      1                 0                           1
# 31306                      0                 1                           1
# 33541                      1                 1                           1
#
#        experience_prediction  politeness_prediction  customization_prediction  \
# 57639                      1                      1                         1
# 43426                      0                      0                         0
# 31306                      1                      0                         0
# 33541                      1                      1                         0
#
#        time_diff_dummy
# 57639                0
# 43426                0
# 31306                1
# 33541                1

# %%
df.to_excel('data_cleaned.xlsx', index=False)

# %% [markdown]
# # 主模型

# %%
import statsmodels.api as sm# 定义自变量和因变量
X = df[['confidence_prediction', 'skill_prediction', 'experience_prediction', 'politeness_prediction', 
        'customization_prediction', 'standardization_prediction', 'std_price', 'DDelivery', 'word', 'time_diff_dummy']]
y = df['std_award_status']

# 添加常数项
X = sm.add_constant(X)

# 逻辑回归模型
model = sm.Logit(y, X)
result = model.fit()

# 展示模型信息
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.051533
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62118
# Method:                           MLE   Df Model:                           10
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03043
# Time:                        13:39:24   Log-Likelihood:                -3201.7
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 1.009e-37
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.0215      0.231    -13.085      0.000      -3.474      -2.569
# confidence_prediction         -0.0946      0.094     -1.006      0.315      -0.279       0.090
# skill_prediction              -0.0539      0.099     -0.545      0.586      -0.248       0.140
# experience_prediction         -0.0765      0.130     -0.586      0.558      -0.332       0.179
# politeness_prediction         -0.0540      0.092     -0.583      0.560      -0.235       0.127
# customization_prediction      -0.3030      0.112     -2.716      0.007      -0.522      -0.084
# standardization_prediction    -0.4439      0.255     -1.739      0.082      -0.944       0.056
# std_price                   1.128e-07   5.31e-07      0.212      0.832   -9.27e-07    1.15e-06
# DDelivery                     -0.0324      0.005     -6.961      0.000      -0.042      -0.023
# word                          -0.0058      0.001     -5.157      0.000      -0.008      -0.004
# time_diff_dummy               -0.2083      0.110     -1.897      0.058      -0.423       0.007
# ==============================================================================================
# """

# %%
import statsmodels.api as sm# 定义自变量和因变量
X = df[[ 
        'customization_prediction', 'standardization_prediction', 'std_price']]
y = df['std_award_status']

# 添加常数项
X = sm.add_constant(X)

# 逻辑回归模型
model = sm.Logit(y, X)
result = model.fit()

# 展示模型信息
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.052699
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62125
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                0.008487
# Time:                        15:15:20   Log-Likelihood:                -3274.1
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 4.099e-12
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.4408      0.227    -15.140      0.000      -3.886      -2.995
# customization_prediction      -0.6155      0.107     -5.768      0.000      -0.825      -0.406
# standardization_prediction    -1.0907      0.231     -4.719      0.000      -1.544      -0.638
# std_price                   -2.59e-07   6.82e-07     -0.380      0.704    -1.6e-06    1.08e-06
# ==============================================================================================
# """

# %%
import statsmodels.api as sm# 定义自变量和因变量
X = df[[ 
        'confidence_prediction', 'skill_prediction', 'experience_prediction', 'politeness_prediction']]
y = df['std_award_status']

# 添加常数项
X = sm.add_constant(X)

# 逻辑回归模型
model = sm.Logit(y, X)
result = model.fit()

# 展示模型信息
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.052779
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62124
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                0.006979
# Time:                        15:19:18   Log-Likelihood:                -3279.1
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 2.358e-09
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -3.9595      0.115    -34.508      0.000      -4.184      -3.735
# confidence_prediction    -0.3206      0.087     -3.665      0.000      -0.492      -0.149
# skill_prediction         -0.1502      0.097     -1.554      0.120      -0.340       0.039
# experience_prediction    -0.3700      0.122     -3.029      0.002      -0.609      -0.131
# politeness_prediction    -0.1652      0.089     -1.860      0.063      -0.339       0.009
# =========================================================================================
# """

# %% [markdown]
# # 交互作用与非线性关系分析

# %% [raw]
# The extended logistic regression model with interaction terms, non-linear effects, and scaled variables has been successfully fitted. Here are the key findings:
#
# Significant Variables:
# DDelivery (交付时间): Coefficient = -0.0350, p-value < 0.001. Longer delivery times reduce the likelihood of bid success.
#
# word (描述字数): Coefficient = -0.0056, p-value < 0.001. Longer bid descriptions negatively impact success.
#
# customization_confidence (个性化与自信的交互项): Coefficient = -0.5951, p-value = 0.006. Customization combined with confidence significantly reduces the likelihood of success.
#
# competition_price (竞争与出价的交互项): Coefficient = -1.286e-06, p-value = 0.002. The interaction between competition and price has a negative effect on bid success. Higher competition with higher prices leads to lower success rates.
#
# DDelivery_squared (交付时间的非线性项): Coefficient = 7.114e-06, p-value < 0.001. There is a non-linear relationship between delivery time and success, suggesting diminishing returns as delivery time increases.
#
# Marginally Significant Variables:
# std_price (出价): Coefficient = 1.339e-05, p-value = 0.063. Price has a marginal positive impact on success.
#
# customization_delivery (个性化与交付时间的交互项): Coefficient = 0.0177, p-value = 0.059. Customization combined with shorter delivery times has a positive (though marginal) effect on success.
#
# time_diff_dummy (时差是否超过八小时): Coefficient = -0.2034, p-value = 0.064. Time differences larger than 8 hours are marginally associated with lower success.
#
# Other Variables:
# scaled_price: Coefficient = -2.442e-05, p-value = 0.229. No significant effect from scaled price.
# experience_confidence: Coefficient = 0.2243, p-value = 0.382. The interaction between experience and confidence is not significant.
# politeness_customization: Coefficient = -0.3288, p-value = 0.154. The interaction between politeness and customization shows no significant effect.
# Summary:
# Delivery time and word count remain strong predictors of bid success.
# Customization combined with confidence negatively impacts success, while customization combined with shorter delivery times has a positive (but marginal) effect.
# Competition plays a significant role in combination with pricing, with more competition and higher prices leading to lower success rates.
# The non-linear relationship of delivery time suggests that after a certain point, increasing delivery time continues to reduce success but with diminishing effects.

# %%
df_full = df.copy()

# %%
# Adding interaction terms for customization with confidence and DDelivery in the full dataset
df_full['customization_confidence'] = df_full['customization_prediction'] * df_full['confidence_prediction']
df_full['customization_delivery'] = df_full['customization_prediction'] * df_full['DDelivery']

# Define the independent variables including interaction terms
X_full = df_full[['confidence_prediction', 'skill_prediction', 'experience_prediction', 'politeness_prediction', 
                  'customization_prediction', 'standardization_prediction', 'std_price', 'DDelivery', 
                  'word', 'time_diff_dummy', 'customization_confidence', 'customization_delivery']]
y_full = df_full['std_award_status']

# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_full.columns
vif_data['VIF'] = [variance_inflation_factor(X_full.values, i) for i in range(X_full.shape[1])]
# 显示 VIF
print(vif_data)

# Add a constant to the model
X_full = sm.add_constant(X_full)

# Fit the logistic regression model with interaction terms
model_full = sm.Logit(y_full, X_full)
result_full = model_full.fit()

# Display the summary of the interaction model
result_full.summary()
# Out:
#                       Variable        VIF
# 0        confidence_prediction   4.514880
# 1             skill_prediction   3.338292
# 2        experience_prediction  11.188935
# 3        politeness_prediction   3.446916
# 4     customization_prediction   5.538293
# 5   standardization_prediction  13.929405
# 6                    std_price   1.013236
# 7                    DDelivery   1.530431
# 8                         word   6.431459
# 9              time_diff_dummy   1.283947
# 10    customization_confidence   4.369765
# 11      customization_delivery   2.286825
# Optimization terminated successfully.
#          Current function value: 0.051447
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62116
# Method:                           MLE   Df Model:                           12
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03203
# Time:                        15:40:54   Log-Likelihood:                -3196.4
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 1.329e-38
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.0103      0.233    -12.941      0.000      -3.466      -2.554
# confidence_prediction          0.0182      0.103      0.177      0.860      -0.183       0.220
# skill_prediction              -0.0453      0.099     -0.457      0.648      -0.240       0.149
# experience_prediction         -0.0869      0.130     -0.666      0.505      -0.343       0.169
# politeness_prediction         -0.0543      0.093     -0.587      0.557      -0.236       0.127
# customization_prediction      -0.2045      0.193     -1.059      0.290      -0.583       0.174
# standardization_prediction    -0.4534      0.255     -1.777      0.076      -0.953       0.047
# std_price                   9.977e-08    5.4e-07      0.185      0.854   -9.59e-07    1.16e-06
# DDelivery                     -0.0387      0.006     -6.616      0.000      -0.050      -0.027
# word                          -0.0058      0.001     -5.196      0.000      -0.008      -0.004
# time_diff_dummy               -0.2006      0.110     -1.827      0.068      -0.416       0.015
# customization_confidence      -0.5661      0.214     -2.643      0.008      -0.986      -0.146
# customization_delivery         0.0184      0.009      1.964      0.049    4.05e-05       0.037
# ==============================================================================================
# """

# %%
# Adding interaction terms for customization with confidence and DDelivery in the full dataset
df_full['customization_confidence'] = df_full['customization_prediction'] * df_full['confidence_prediction']
df_full['customization_delivery'] = df_full['customization_prediction'] * df_full['DDelivery']

# Define the independent variables including interaction terms
X_full = df_full[[ 'confidence_prediction',
                  'customization_prediction', 'standardization_prediction',  'customization_confidence']]
y_full = df_full['std_award_status']
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_full.columns
vif_data['VIF'] = [variance_inflation_factor(X_full.values, i) for i in range(X_full.shape[1])]
# 显示 VIF
print(vif_data)
# Add a constant to the model
X_full = sm.add_constant(X_full)

# Fit the logistic regression model with interaction terms
model_full = sm.Logit(y_full, X_full)
result_full = model_full.fit()

# Display the summary of the interaction model
result_full.summary()
# Out:
#                      Variable       VIF
# 0       confidence_prediction  3.905587
# 1    customization_prediction  4.221570
# 2  standardization_prediction  3.788274
# 3    customization_confidence  4.338877
# Optimization terminated successfully.
#          Current function value: 0.052523
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62124
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.01179
# Time:                        15:44:51   Log-Likelihood:                -3263.2
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 4.912e-16
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.4688      0.228    -15.230      0.000      -3.915      -3.022
# confidence_prediction         -0.2615      0.095     -2.766      0.006      -0.447      -0.076
# customization_prediction      -0.3322      0.152     -2.186      0.029      -0.630      -0.034
# standardization_prediction    -0.9078      0.236     -3.851      0.000      -1.370      -0.446
# customization_confidence      -0.4838      0.214     -2.265      0.024      -0.902      -0.065
# ==============================================================================================
# """

# %% [markdown]
# ## BETTER RESULT

# %%
# Adding interaction terms for customization with confidence and DDelivery in the full dataset
df_full['customization_confidence'] = df_full['customization_prediction'] * df_full['confidence_prediction']
df_full['customization_delivery'] = df_full['customization_prediction'] * df_full['DDelivery']

# Define the independent variables including interaction terms
X_full = df_full[[ 'confidence_prediction',
                  'customization_prediction', 'standardization_prediction', 'customization_confidence' ,'DDelivery', 
                  'word', 'time_diff_dummy']]
y_full = df_full['std_award_status']
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_full.columns
vif_data['VIF'] = [variance_inflation_factor(X_full.values, i) for i in range(X_full.shape[1])]
# 显示 VIF
print(vif_data)
# Add a constant to the model
X_full = sm.add_constant(X_full)

# Fit the logistic regression model with interaction terms
model_full = sm.Logit(y_full, X_full)
result_full = model_full.fit()

# Display the summary of the interaction model
result_full.summary()
# Out:
#                      Variable       VIF
# 0       confidence_prediction  4.436141
# 1    customization_prediction  4.391785
# 2  standardization_prediction  6.018752
# 3    customization_confidence  4.348176
# 4                   DDelivery  1.315623
# 5                        word  5.933216
# 6             time_diff_dummy  1.280998
# Optimization terminated successfully.
#          Current function value: 0.051488
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62121
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03127
# Time:                        18:11:16   Log-Likelihood:                -3198.9
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 4.788e-41
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.0593      0.231    -13.227      0.000      -3.513      -2.606
# confidence_prediction         -0.0006      0.102     -0.005      0.996      -0.200       0.199
# customization_prediction       0.0066      0.155      0.042      0.966      -0.298       0.311
# standardization_prediction    -0.5565      0.239     -2.331      0.020      -1.025      -0.089
# customization_confidence      -0.5589      0.214     -2.613      0.009      -0.978      -0.140
# DDelivery                     -0.0327      0.005     -7.025      0.000      -0.042      -0.024
# word                          -0.0062      0.001     -5.777      0.000      -0.008      -0.004
# time_diff_dummy               -0.1997      0.110     -1.820      0.069      -0.415       0.015
# ==============================================================================================
# """

# %%
# Adding interaction terms for customization with confidence and DDelivery in the full dataset
df_full['scaled_price'] = df_full['std_price'] / (df_full['competition'] + 1)  # adding 1 to avoid division by zero

df_full['customization_confidence'] = df_full['customization_prediction'] * df_full['confidence_prediction']
df_full['customization_politeness'] = df_full['customization_prediction'] * df_full['politeness_prediction']
df_full['customization_skill'] = df_full['customization_prediction'] * df_full['skill_prediction']

df_full['customization_delivery'] = df_full['customization_prediction'] * df_full['DDelivery']
df_full['customization_price'] = df_full['customization_prediction'] * df_full['scaled_price']

#强烈多重共线df_full['standardization_price'] = df_full['standardization_prediction'] * df_full['scaled_price']

# Define the independent variables including interaction terms
X_full = df_full[['scaled_price', 'confidence_prediction','politeness_prediction',
                  'customization_prediction','skill_prediction', 
                  'customization_confidence' ,'customization_politeness','customization_skill',
                 
                  'DDelivery', 
                  'word', 'time_diff_dummy']]
y_full = df_full['std_award_status']
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_full.columns
vif_data['VIF'] = [variance_inflation_factor(X_full.values, i) for i in range(X_full.shape[1])]
# 显示 VIF
print(vif_data)
# Add a constant to the model
X_full = sm.add_constant(X_full)

# Fit the logistic regression model with interaction terms
model_full = sm.Logit(y_full, X_full)
result_full = model_full.fit()

# Display the summary of the interaction model
result_full.summary()
# Out:
#                     Variable       VIF
# 0               scaled_price  1.003679
# 1      confidence_prediction  4.263962
# 2      politeness_prediction  3.229858
# 3   customization_prediction  8.780771
# 4           skill_prediction  3.556644
# 5   customization_confidence  4.444963
# 6   customization_politeness  5.126652
# 7        customization_skill  3.617934
# 8                  DDelivery  1.298834
# 9                       word  5.758540
# 10           time_diff_dummy  1.257750
# Optimization terminated successfully.
#          Current function value: 0.051421
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62117
# Method:                           MLE   Df Model:                           11
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03253
# Time:                        18:30:27   Log-Likelihood:                -3194.7
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 6.116e-40
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -3.4790      0.115    -30.177      0.000      -3.705      -3.253
# scaled_price              4.894e-06   1.79e-06      2.733      0.006    1.38e-06     8.4e-06
# confidence_prediction        0.0066      0.101      0.065      0.948      -0.192       0.205
# politeness_prediction       -0.0501      0.099     -0.508      0.612      -0.244       0.143
# customization_prediction    -0.0386      0.258     -0.150      0.881      -0.544       0.467
# skill_prediction            -0.1957      0.100     -1.959      0.050      -0.391       0.000
# customization_confidence    -0.6663      0.220     -3.033      0.002      -1.097      -0.236
# customization_politeness    -0.2704      0.232     -1.166      0.243      -0.725       0.184
# customization_skill          0.5124      0.226      2.263      0.024       0.069       0.956
# DDelivery                   -0.0332      0.005     -7.153      0.000      -0.042      -0.024
# word                        -0.0060      0.001     -5.404      0.000      -0.008      -0.004
# time_diff_dummy             -0.1942      0.110     -1.769      0.077      -0.409       0.021
# ============================================================================================
# """

# %% [markdown]
# # 拆分策略

# %%
# Adding interaction terms for customization with confidence and DDelivery in the full dataset
#df_full['skill_confidence'] = df_full['skill_prediction'] * df_full['confidence_prediction']
##df_full['experience_confidence'] = df_full['experience_prediction'] * df_full['confidence_prediction']
df_full['politeness_confidence'] = df_full['politeness_prediction'] * df_full['confidence_prediction']
##df_full['skill_experience'] = df_full['skill_prediction'] * df_full['experience_prediction']
df_full['skill_politeness'] = df_full['skill_prediction'] * df_full['politeness_prediction']
##df_full['experience_politeness'] = df_full['experience_prediction'] * df_full['politeness_prediction']


# Define the independent variables including interaction terms
X_full = df_full[[ 'skill_prediction', 'politeness_prediction',
                
                  'skill_politeness',
                   'std_price', 'DDelivery', 
                  'word', 'time_diff_dummy']]
y_full = df_full['std_award_status']
y_full = df_full['std_award_status']
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_full.columns
vif_data['VIF'] = [variance_inflation_factor(X_full.values, i) for i in range(X_full.shape[1])]
# 显示 VIF
print(vif_data)
# Add a constant to the model
X_full = sm.add_constant(X_full)

# Fit the logistic regression model with interaction terms
model_full = sm.Logit(y_full, X_full)
result_full = model_full.fit()

# Display the summary of the interaction model
result_full.summary()
# Out:
#                 Variable       VIF
# 0       skill_prediction  5.099850
# 1  politeness_prediction  4.222310
# 2       skill_politeness  4.972968
# 3              std_price  1.012572
# 4              DDelivery  1.304536
# 5                   word  4.421753
# 6        time_diff_dummy  1.262006
# Optimization terminated successfully.
#          Current function value: 0.051621
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62121
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.02878
# Time:                        17:44:47   Log-Likelihood:                -3207.1
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 1.471e-37
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -3.3611      0.125    -26.851      0.000      -3.606      -3.116
# skill_prediction         -0.2464      0.148     -1.659      0.097      -0.537       0.045
# politeness_prediction    -0.2376      0.133     -1.783      0.075      -0.499       0.024
# skill_politeness          0.2307      0.177      1.300      0.193      -0.117       0.578
# std_price              9.708e-08   5.39e-07      0.180      0.857   -9.59e-07    1.15e-06
# DDelivery                -0.0333      0.005     -7.124      0.000      -0.042      -0.024
# word                     -0.0073      0.001     -7.170      0.000      -0.009      -0.005
# time_diff_dummy          -0.2186      0.110     -1.992      0.046      -0.434      -0.004
# =========================================================================================
# """

# %% [markdown]
# # experience

# %%
# Adding interaction terms for experience and confidence, politeness and customization
df_full['experience_confidence'] = df_full['experience_prediction'] * df_full['confidence_prediction']
df_full['politeness_customization'] = df_full['politeness_prediction'] * df_full['customization_prediction']


# Adding non-linear terms for std_price and DDelivery
df_full['std_price_squared'] = df_full['std_price'] ** 2

# Scaled price: std_price / competition (normalizing by competition level)
df_full['scaled_price'] = df_full['std_price'] / (df_full['competition'] + 1)  # adding 1 to avoid division by zero

# Adding the competition variable and interaction with std_price
df_full['competition_price'] = df_full['competition'] * df_full['std_price_squared']
# Define the independent variables including these new terms
X_extended = df_full[['confidence_prediction', 'skill_prediction', 'experience_prediction', 'politeness_prediction', 
                      'customization_prediction', 'standardization_prediction', 'DDelivery', 'word', 
                      'time_diff_dummy', 'customization_confidence', 'customization_delivery', 
                      'experience_confidence', 'politeness_customization', 'competition_price', 
                      'std_price_squared',  'scaled_price']]
y_extended = df_full['std_award_status']
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_extended.columns
vif_data['VIF'] = [variance_inflation_factor(X_extended.values, i) for i in range(X_extended.shape[1])]
# 显示 VIF
print(vif_data)

# Add a constant to the model
X_extended = sm.add_constant(X_extended)

# Fit the logistic regression model with extended terms
model_extended = sm.Logit(y_extended, X_extended)
result_extended = model_extended.fit()

# Display the summary of the extended model
result_extended.summary()
# Out:
#                       Variable        VIF
# 0        confidence_prediction   9.417810
# 1             skill_prediction   1.296864
# 2        experience_prediction   2.082813
# 3        politeness_prediction   1.441224
# 4     customization_prediction   6.721579
# 5   standardization_prediction   0.214846
# 6                    DDelivery   1.178858
# 7                         word   1.414143
# 8              time_diff_dummy   1.003785
# 9     customization_confidence   3.492793
# 10      customization_delivery   1.959605
# 11       experience_confidence  10.599707
# 12    politeness_customization   4.219874
# 13           competition_price   4.547068
# 14           std_price_squared   6.310091
# 15                scaled_price   2.394488
# Optimization terminated successfully.
#          Current function value: 0.051334
#          Iterations 16
# C:\Users\ergo_user\anaconda3\Lib\site-packages\statsmodels\discrete\discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\ergo_user\anaconda3\Lib\site-packages\statsmodels\discrete\discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62112
# Method:                           MLE   Df Model:                           16
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03417
# Time:                        16:27:41   Log-Likelihood:                -3189.3
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 4.870e-39
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.0344      0.234    -12.963      0.000      -3.493      -2.576
# confidence_prediction         -0.1628      0.242     -0.672      0.502      -0.638       0.312
# skill_prediction              -0.0502      0.099     -0.506      0.613      -0.245       0.144
# experience_prediction         -0.1554      0.152     -1.023      0.306      -0.453       0.142
# politeness_prediction         -0.0033      0.101     -0.032      0.974      -0.202       0.195
# customization_prediction       0.0570      0.251      0.227      0.820      -0.434       0.549
# standardization_prediction    -0.4137      0.260     -1.593      0.111      -0.923       0.095
# DDelivery                     -0.0380      0.006     -6.488      0.000      -0.050      -0.027
# word                          -0.0058      0.001     -5.129      0.000      -0.008      -0.004
# time_diff_dummy               -0.2039      0.110     -1.857      0.063      -0.419       0.011
# customization_confidence      -0.5933      0.215     -2.760      0.006      -1.015      -0.172
# customization_delivery         0.0176      0.009      1.872      0.061      -0.001       0.036
# experience_confidence          0.2112      0.256      0.824      0.410      -0.291       0.714
# politeness_customization      -0.3306      0.230     -1.437      0.151      -0.782       0.120
# competition_price          -1.635e-12   1.41e-12     -1.163      0.245   -4.39e-12    1.12e-12
# std_price_squared           5.405e-12   4.55e-12      1.189      0.234    -3.5e-12    1.43e-11
# scaled_price                1.802e-06   1.91e-05      0.094      0.925   -3.57e-05    3.93e-05
# ==============================================================================================
# """

# %%
# Adding interaction terms for experience and confidence, politeness and customization
df_full['experience_confidence'] = df_full['experience_prediction'] * df_full['confidence_prediction']
df_full['politeness_customization'] = df_full['politeness_prediction'] * df_full['customization_prediction']


# Adding non-linear terms for std_price and DDelivery
df_full['std_price_squared'] = df_full['std_price'] ** 2

# Scaled price: std_price / competition (normalizing by competition level)
df_full['scaled_price'] = df_full['std_price'] / (df_full['competition'] + 1)  # adding 1 to avoid division by zero

# Adding the competition variable and interaction with std_price
df_full['competition_price'] = df_full['competition'] * df_full['scaled_price']
# Define the independent variables including these new terms
X_extended = df_full[['confidence_prediction',  'experience_prediction', 'politeness_prediction', 'customization_prediction',
                      'DDelivery', 'word', 
                      'competition',
                      'experience_confidence', 'politeness_customization', 'competition_price', 
                      'std_price_squared',  'scaled_price']]
y_extended = df_full['std_award_status']
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_extended.columns
vif_data['VIF'] = [variance_inflation_factor(X_extended.values, i) for i in range(X_extended.shape[1])]
# 显示 VIF
print(vif_data)

# Add a constant to the model
X_extended = sm.add_constant(X_extended)

# Fit the logistic regression model with extended terms
model_extended = sm.Logit(y_extended, X_extended)
result_extended = model_extended.fit()

# Display the summary of the extended model
result_extended.summary()
# Out:
#                     Variable       VIF
# 0      confidence_prediction  6.960971
# 1      experience_prediction  0.887755
# 2      politeness_prediction  1.190528
# 3   customization_prediction  3.747774
# 4                  DDelivery  1.038131
# 5                       word  1.361179
# 6                competition  0.990055
# 7      experience_confidence  8.024843
# 8   politeness_customization  4.074952
# 9          competition_price  3.308285
# 10         std_price_squared  2.797323
# 11              scaled_price  3.302745
# Optimization terminated successfully.
#          Current function value: 0.049163
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                62129
# Model:                          Logit   Df Residuals:                    62116
# Method:                           MLE   Df Model:                           12
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.07501
# Time:                        17:14:24   Log-Likelihood:                -3054.5
# converged:                       True   LL-Null:                       -3302.2
# Covariance Type:            nonrobust   LLR p-value:                 2.126e-98
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -2.7160      0.137    -19.815      0.000      -2.985      -2.447
# confidence_prediction       -0.2489      0.236     -1.053      0.292      -0.712       0.214
# experience_prediction       -0.1864      0.136     -1.367      0.172      -0.454       0.081
# politeness_prediction        0.0405      0.098      0.413      0.679      -0.152       0.233
# customization_prediction     0.0948      0.194      0.488      0.626      -0.286       0.475
# DDelivery                   -0.0155      0.004     -3.489      0.000      -0.024      -0.007
# word                        -0.0045      0.001     -4.137      0.000      -0.007      -0.002
# competition                 -0.0347      0.002    -14.072      0.000      -0.040      -0.030
# experience_confidence        0.2224      0.252      0.883      0.377      -0.271       0.716
# politeness_customization    -0.4110      0.230     -1.784      0.074      -0.863       0.041
# competition_price        -1.208e-05   4.42e-06     -2.732      0.006   -2.07e-05   -3.41e-06
# std_price_squared         7.153e-13   2.95e-13      2.426      0.015    1.37e-13    1.29e-12
# scaled_price              3.321e-05   1.06e-05      3.124      0.002    1.24e-05    5.41e-05
# ============================================================================================
# """

# %% [raw]
# 进行子样本分析，我们可以按 std_price 和 competition 等变量进行分组，分别分析每个子样本中 customization_prediction 对竞标成功（std_award_status）的影响。我们可以将 std_price 和 competition 分别分为几个范围区间，然后在每个区间内单独拟合逻辑回归模型，看看个性化策略是否在某些条件下有利
#
# 分析步骤：
# 按 std_price 进行分组：
# 将价格按低、中、高区间分组。
# 按 competition 进行分组：
# 按竞争者数量分为低竞争和高竞争组。
# 子样本分析：
# 在不同的 std_price 和 competition 区间中，分别拟合逻辑回归模型，观察 customization_prediction 的系数及其显著性。
# 让我们先按 std_price 和 competition 进行分组，并分别拟合模型。
#
# 以下是子样本分析的关键结果，根据 std_price 和 competition 分组后的分析：
#
# 中等价格、低竞争组：
#
# customization_prediction (个性化策略) 的系数为 0.1978，p 值为 0.554，表明在 中等价格和低竞争环境下，个性化策略对竞标成功没有显著影响。
# standardization_prediction (标准化策略) 的系数为 -0.7648，p 值为 0.085，接近显著水平（p < 0.1），可能在此环境下标准化策略有负面影响。
# 模型整体显著性（LLR p-value = 0.0001464）显示这个子样本中的整体模型有统计意义。
# 低价格、高竞争组：
#
# customization_prediction 的系数为 -1.4807，p 值为 0.079，接近显著水平，表明在 低价格、高竞争环境下，个性化策略可能有负面影响，个性化策略可能不适合高竞争和低出价的环境。
# customization_delivery (个性化策略和交付时间的交互项) 的系数为 0.0507，p 值为 0.058，接近显著，说明在个性化策略与较短交付时间结合时，可能有正面影响。
# 关键结论：
# 在中等价格和低竞争环境下，个性化策略对竞标成功没有显著影响，而标准化策略可能不利于竞标成功。
# 在低价格和高竞争环境下，个性化策略对竞标成功的影响接近显著的负面作用，这表明在这种环境下使用个性化策略可能适得其反。但结合较短交付时间，个性化策略可能会改善成功率。

# %%
# Create bins for std_price and competition
df_full['price_group'] = pd.qcut(df_full['std_price'], 3, labels=['low_price', 'medium_price', 'high_price'])
df_full['competition_group'] = pd.qcut(df_full['competition'], 2, labels=['low_competition', 'high_competition'])

# Function to run logistic regression for a given subset of data
def run_logit_for_subset(subset_df):
    # Define the independent variables
    X_subset = subset_df[['confidence_prediction', 'skill_prediction', 'experience_prediction', 'politeness_prediction', 
                          'customization_prediction', 'standardization_prediction', 'DDelivery', 'word', 
                          'time_diff_dummy', 'customization_confidence', 'customization_delivery']]
    y_subset = subset_df['std_award_status']
    
    # Add a constant to the model
    X_subset = sm.add_constant(X_subset)
    
    # Fit the logistic regression model
    model = sm.Logit(y_subset, X_subset)
    result = model.fit(disp=False)
    return result

# Split data by price_group and competition_group, then run the model for each subset
results = {}

for price_group in df_full['price_group'].unique():
    for competition_group in df_full['competition_group'].unique():
        subset_df = df_full[(df_full['price_group'] == price_group) & (df_full['competition_group'] == competition_group)]
        if not subset_df.empty:
            result = run_logit_for_subset(subset_df)
            results[(price_group, competition_group)] = result.summary()

# Display the summary for each subset analysis
results
# Out:
# C:\Users\ergo_user\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# {('medium_price',
#   'low_competition'): <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                12672
#  Model:                          Logit   Df Residuals:                    12659
#  Method:                           MLE   Df Model:                           12
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.02255
#  Time:                        14:06:50   Log-Likelihood:                -826.33
#  converged:                       True   LL-Null:                       -845.40
#  Covariance Type:            nonrobust   LLR p-value:                 0.0001464
#  ==============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------
#  const                         -2.8787      0.405     -7.115      0.000      -3.672      -2.086
#  confidence_prediction         -0.0422      0.198     -0.213      0.831      -0.430       0.346
#  skill_prediction              -0.2575      0.186     -1.382      0.167      -0.623       0.108
#  experience_prediction          0.2801      0.255      1.099      0.272      -0.220       0.780
#  politeness_prediction         -0.1787      0.174     -1.029      0.303      -0.519       0.162
#  customization_prediction       0.1978      0.334      0.592      0.554      -0.457       0.853
#  standardization_prediction    -0.7648      0.444     -1.721      0.085      -1.636       0.106
#  std_price                     -0.0009      0.000     -2.050      0.040      -0.002   -4.01e-05
#  DDelivery                      0.0015      0.004      0.351      0.725      -0.007       0.010
#  word                          -0.0043      0.002     -2.010      0.044      -0.009      -0.000
#  time_diff_dummy               -0.1997      0.233     -0.859      0.391      -0.656       0.256
#  customization_confidence      -0.9479      0.420     -2.255      0.024      -1.772      -0.124
#  customization_delivery         0.0010      0.014      0.068      0.946      -0.027       0.029
#  ==============================================================================================
#  """,
#  ('medium_price',
#   'high_competition'): <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                 8026
#  Model:                          Logit   Df Residuals:                     8013
#  Method:                           MLE   Df Model:                           12
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03522
#  Time:                        14:06:50   Log-Likelihood:                -258.31
#  converged:                       True   LL-Null:                       -267.74
#  Covariance Type:            nonrobust   LLR p-value:                   0.09194
#  ==============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------
#  const                         -3.6480      1.083     -3.367      0.001      -5.771      -1.525
#  confidence_prediction          0.7512      0.447      1.682      0.093      -0.124       1.627
#  skill_prediction               0.4307      0.366      1.177      0.239      -0.287       1.148
#  experience_prediction          0.5114      0.631      0.810      0.418      -0.726       1.749
#  politeness_prediction          0.1810      0.350      0.517      0.605      -0.505       0.867
#  customization_prediction       0.7944      0.663      1.198      0.231      -0.505       2.094
#  standardization_prediction    -1.4159      1.157     -1.224      0.221      -3.684       0.852
#  std_price                     -0.0012      0.001     -1.581      0.114      -0.003       0.000
#  DDelivery                     -0.0021      0.013     -0.161      0.872      -0.028       0.024
#  word                          -0.0138      0.004     -3.167      0.002      -0.022      -0.005
#  time_diff_dummy                0.2059      0.335      0.614      0.539      -0.451       0.863
#  customization_confidence      -0.6541      0.698     -0.938      0.348      -2.021       0.713
#  customization_delivery        -0.0032      0.020     -0.161      0.872      -0.042       0.036
#  ==============================================================================================
#  """,
#  ('high_price',
#   'low_competition'): <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                 8004
#  Model:                          Logit   Df Residuals:                     7991
#  Method:                           MLE   Df Model:                           12
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.02341
#  Time:                        14:06:50   Log-Likelihood:                -325.88
#  converged:                       True   LL-Null:                       -333.69
#  Covariance Type:            nonrobust   LLR p-value:                    0.2090
#  ==============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------
#  const                         -3.4954      0.731     -4.782      0.000      -4.928      -2.063
#  confidence_prediction          0.1365      0.326      0.418      0.676      -0.503       0.776
#  skill_prediction               0.3303      0.344      0.960      0.337      -0.344       1.005
#  experience_prediction         -0.2651      0.458     -0.578      0.563      -1.163       0.633
#  politeness_prediction         -0.0950      0.289     -0.329      0.742      -0.662       0.471
#  customization_prediction      -0.7956      0.846     -0.941      0.347      -2.453       0.862
#  standardization_prediction    -0.6275      0.813     -0.772      0.440      -2.221       0.966
#  std_price                   3.126e-07   3.37e-07      0.926      0.354   -3.49e-07    9.74e-07
#  DDelivery                     -0.0159      0.011     -1.435      0.151      -0.037       0.006
#  word                          -0.0054      0.003     -1.581      0.114      -0.012       0.001
#  time_diff_dummy               -0.1080      0.408     -0.265      0.791      -0.907       0.692
#  customization_confidence       0.8146      0.850      0.959      0.338      -0.851       2.480
#  customization_delivery        -0.0090      0.025     -0.356      0.722      -0.059       0.041
#  ==============================================================================================
#  """,
#  ('high_price',
#   'high_competition'): <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                12705
#  Model:                          Logit   Df Residuals:                    12692
#  Method:                           MLE   Df Model:                           12
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.05002
#  Time:                        14:06:50   Log-Likelihood:                -200.85
#  converged:                       True   LL-Null:                       -211.42
#  Covariance Type:            nonrobust   LLR p-value:                   0.04822
#  ==============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------
#  const                         -3.7541      1.044     -3.596      0.000      -5.800      -1.708
#  confidence_prediction         -0.2192      0.445     -0.493      0.622      -1.091       0.653
#  skill_prediction              -0.3314      0.428     -0.775      0.438      -1.170       0.507
#  experience_prediction          0.1491      0.576      0.259      0.796      -0.979       1.278
#  politeness_prediction         -0.3174      0.401     -0.791      0.429      -1.104       0.469
#  customization_prediction      -1.0442      0.825     -1.265      0.206      -2.662       0.573
#  standardization_prediction    -0.8743      1.139     -0.768      0.443      -3.106       1.358
#  std_price                   -1.01e-05   1.58e-05     -0.638      0.523   -4.11e-05    2.09e-05
#  DDelivery                     -0.0012      0.009     -0.136      0.892      -0.018       0.016
#  word                          -0.0059      0.005     -1.290      0.197      -0.015       0.003
#  time_diff_dummy               -0.4373      0.460     -0.952      0.341      -1.338       0.463
#  customization_confidence      -1.4654      1.190     -1.231      0.218      -3.798       0.867
#  customization_delivery         0.0178      0.015      1.164      0.244      -0.012       0.048
#  ==============================================================================================
#  """,
#  ('low_price',
#   'low_competition'): <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                10827
#  Model:                          Logit   Df Residuals:                    10814
#  Method:                           MLE   Df Model:                           12
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.04550
#  Time:                        14:06:50   Log-Likelihood:                -1167.1
#  converged:                       True   LL-Null:                       -1222.7
#  Covariance Type:            nonrobust   LLR p-value:                 3.344e-18
#  ==============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------
#  const                         -2.7809      0.361     -7.701      0.000      -3.489      -2.073
#  confidence_prediction          0.1519      0.158      0.960      0.337      -0.158       0.462
#  skill_prediction              -0.0547      0.154     -0.355      0.723      -0.357       0.247
#  experience_prediction         -0.2277      0.191     -1.194      0.233      -0.602       0.146
#  politeness_prediction          0.0296      0.143      0.206      0.836      -0.251       0.310
#  customization_prediction      -0.0478      0.308     -0.155      0.877      -0.652       0.557
#  standardization_prediction    -0.0554      0.381     -0.146      0.884      -0.802       0.691
#  std_price                      0.0166      0.004      3.899      0.000       0.008       0.025
#  DDelivery                     -0.1163      0.020     -5.945      0.000      -0.155      -0.078
#  word                          -0.0023      0.002     -1.324      0.186      -0.006       0.001
#  time_diff_dummy               -0.0916      0.169     -0.543      0.587      -0.422       0.239
#  customization_confidence      -0.8705      0.343     -2.541      0.011      -1.542      -0.199
#  customization_delivery         0.0686      0.030      2.273      0.023       0.009       0.128
#  ==============================================================================================
#  """,
#  ('low_price',
#   'high_competition'): <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                 9895
#  Model:                          Logit   Df Residuals:                     9882
#  Method:                           MLE   Df Model:                           12
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.03362
#  Time:                        14:06:50   Log-Likelihood:                -240.91
#  converged:                      False   LL-Null:                       -249.29
#  Covariance Type:            nonrobust   LLR p-value:                    0.1587
#  ==============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------
#  const                        -31.9424   1.17e+06  -2.73e-05      1.000   -2.29e+06    2.29e+06
#  confidence_prediction         -0.4491      0.399     -1.127      0.260      -1.230       0.332
#  skill_prediction              -0.4832      0.384     -1.259      0.208      -1.235       0.269
#  experience_prediction         -0.5726      0.514     -1.113      0.266      -1.581       0.436
#  politeness_prediction          0.4578      0.424      1.080      0.280      -0.373       1.288
#  customization_prediction      -1.4807      0.844     -1.754      0.079      -3.135       0.173
#  standardization_prediction    27.0484   1.17e+06   2.31e-05      1.000   -2.29e+06    2.29e+06
#  std_price                     -0.0210      0.015     -1.401      0.161      -0.050       0.008
#  DDelivery                     -0.0144      0.021     -0.675      0.499      -0.056       0.027
#  word                           0.0069      0.004      1.813      0.070      -0.001       0.014
#  time_diff_dummy                0.1072      0.370      0.290      0.772      -0.618       0.833
#  customization_confidence      -0.1662      0.855     -0.194      0.846      -1.842       1.509
#  customization_delivery         0.0507      0.027      1.899      0.058      -0.002       0.103
#  ==============================================================================================
#  """}

# %% [markdown]
# # focus on specific strategies in high-competition settings

# %% [raw]
# To focus on specific strategies in high-competition settings, we can isolate the data for high competition and analyze the impact of various strategies like customization, standardization, confidence, and their interactions (e.g., with price and delivery time). This will allow us to see which strategies work best in competitive environments.
#
# Steps:
# Isolate the high-competition group: Filter the dataset to only include the high-competition setting.
# Run logistic regression: Focus on the key strategic variables and their interactions, particularly how customization, confidence, experience, and other strategies interact with competition.
# Analyze results: Determine which strategies are significant in high-competition environments.
# Let’s first isolate the high-competition data and analyze the impact of key strategies.
#
# In the high-competition setting, the logistic regression results show the impact of key strategies. Here are the main findings:
#
# Key Variables in High-Competition Settings:
# confidence_prediction (是否自信): Coefficient = 0.0642, p-value = 0.792. Confidence does not have a significant effect on success in a high-competition environment.
#
# skill_prediction (是否提及技能): Coefficient = -0.0641, p-value = 0.772. Mentioning skills also does not show a significant impact in this environment.
#
# experience_prediction (是否提及经验): Coefficient = 0.0017, p-value = 0.996. Experience has no effect in high-competition settings.
#
# customization_prediction (是否采用个性化策略): Coefficient = -0.2486, p-value = 0.534. Customization does not show a significant effect on success, indicating that personalizing bids may not help in high-competition settings.
#
# standardization_prediction (是否采用标准化策略): Coefficient = -0.5925, p-value = 0.444. Standardization also shows no significant effect.
#
# word (描述字数): Coefficient = -0.0052, p-value = 0.033. Longer descriptions have a significant negative effect, meaning shorter bids are more successful in high-competition scenarios.
#
# customization_confidence (个性化与自信的交互项): Coefficient = -0.4133, p-value = 0.359. The interaction between customization and confidence does not show significance.
#
# customization_delivery (个性化与交付时间的交互项): Coefficient = 0.0081, p-value = 0.396. This interaction is not significant either.
#
# Summary for High-Competition Strategies:
# Shorter bids are more successful in high-competition environments (word count has a negative effect).
# Customization and confidence do not play a significant role in determining success in these settings.
# Neither customization nor standardization are effective strategies in highly competitive environments.

# %%
# Filter data for high-competition settings
high_competition_df = df_full[df_full['competition_group'] == 'high_competition']

# Define the independent variables for high-competition settings
X_high_competition = high_competition_df[['confidence_prediction', 'skill_prediction', 'experience_prediction', 
                                          'politeness_prediction', 'customization_prediction', 
                                          'standardization_prediction', 'std_price', 'DDelivery', 'word', 
                                          'time_diff_dummy', 'customization_confidence', 'customization_delivery']]

# Define the dependent variable
y_high_competition = high_competition_df['std_award_status']

# Add a constant to the model
X_high_competition = sm.add_constant(X_high_competition)

# Fit the logistic regression model for high-competition data
model_high_competition = sm.Logit(y_high_competition, X_high_competition)
result_high_competition = model_high_competition.fit()

# Display the summary of the high-competition model
result_high_competition.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.023670
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                30626
# Model:                          Logit   Df Residuals:                    30613
# Method:                           MLE   Df Model:                           12
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.01322
# Time:                        14:09:23   Log-Likelihood:                -724.92
# converged:                       True   LL-Null:                       -734.63
# Covariance Type:            nonrobust   LLR p-value:                   0.07881
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -4.3514      0.723     -6.018      0.000      -5.769      -2.934
# confidence_prediction          0.0642      0.244      0.264      0.792      -0.413       0.542
# skill_prediction              -0.0641      0.221     -0.289      0.772      -0.498       0.370
# experience_prediction          0.0017      0.323      0.005      0.996      -0.631       0.634
# politeness_prediction          0.0723      0.219      0.330      0.742      -0.358       0.502
# customization_prediction      -0.2486      0.400     -0.622      0.534      -1.033       0.535
# standardization_prediction    -0.5925      0.773     -0.766      0.444      -2.108       0.923
# std_price                  -2.371e-05   2.27e-05     -1.044      0.297   -6.82e-05    2.08e-05
# DDelivery                     -0.0052      0.007     -0.697      0.486      -0.020       0.009
# word                          -0.0052      0.002     -2.138      0.033      -0.010      -0.000
# time_diff_dummy                0.0041      0.217      0.019      0.985      -0.421       0.429
# customization_confidence      -0.4133      0.451     -0.917      0.359      -1.297       0.470
# customization_delivery         0.0081      0.010      0.849      0.396      -0.011       0.027
# ==============================================================================================
# """

# %% [markdown]
# # examine only customization impact

# %% [raw]
# To focus exclusively on the impact of customization in high-competition settings, we can simplify the model to only include customization-related variables and control for basic factors like delivery time, word count, and price. This will allow us to specifically assess whether customization itself has a significant effect in high-competition environments.
#
# Steps:
# Isolate the key variables: Focus on customization_prediction, its interactions (customization_confidence, customization_delivery), and control variables such as std_price, DDelivery, and word.
# Fit the logistic regression model: Use only customization-related variables to see their specific impact.
# Analyze results: Determine if customization has a significant role in high-competition settings.
# Let’s proceed with this focused analysis.
#
# The logistic regression model focusing exclusively on customization in high-competition settings provides the following insights:
#
# Key Findings:
# customization_prediction (个性化策略): Coefficient = -0.2694, p-value = 0.463. Customization itself does not have a significant effect on success in high-competition environments.
#
# customization_confidence (个性化与自信的交互项): Coefficient = -0.3704, p-value = 0.351. The interaction between customization and confidence is also not significant.
#
# customization_delivery (个性化与交付时间的交互项): Coefficient = 0.0084, p-value = 0.382. The interaction between customization and delivery time does not show significance.
#
# std_price (出价): Coefficient = -2.365e-05, p-value = 0.294. Price does not show a significant impact.
#
# DDelivery (交付时间): Coefficient = -0.0055, p-value = 0.460. Delivery time does not have a significant impact in this focused model.
#
# word (描述字数): Coefficient = -0.0053, p-value = 0.014. Shorter descriptions are significantly more likely to succeed in high-competition settings.
#
# Summary:
# Customization alone does not have a significant impact on bid success in high-competition environments.
# Shorter bid descriptions are a significant factor, showing that concise bids are more effective when competition is intense.
# The interactions between customization and confidence or delivery time do not play a significant role in this scenario.

# %%
# Define the independent variables focusing on customization and control variables
X_customization_only = high_competition_df[['customization_prediction', 'customization_confidence', 
                                            'customization_delivery', 'std_price', 'DDelivery', 'word']]

# Define the dependent variable
y_customization_only = high_competition_df['std_award_status']

# Add a constant to the model
X_customization_only = sm.add_constant(X_customization_only)

# Fit the logistic regression model for high-competition data, focusing on customization
model_customization_only = sm.Logit(y_customization_only, X_customization_only)
result_customization_only = model_customization_only.fit()

# Display the summary of the customization-only model
result_customization_only.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.023683
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                30626
# Model:                          Logit   Df Residuals:                    30619
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.01268
# Time:                        14:09:29   Log-Likelihood:                -725.31
# converged:                       True   LL-Null:                       -734.63
# Covariance Type:            nonrobust   LLR p-value:                  0.004827
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -4.8614      0.231    -21.063      0.000      -5.314      -4.409
# customization_prediction    -0.2694      0.367     -0.734      0.463      -0.989       0.450
# customization_confidence    -0.3704      0.397     -0.932      0.351      -1.149       0.408
# customization_delivery       0.0084      0.010      0.874      0.382      -0.010       0.027
# std_price                -2.365e-05   2.26e-05     -1.048      0.294   -6.79e-05    2.06e-05
# DDelivery                   -0.0055      0.007     -0.739      0.460      -0.020       0.009
# word                        -0.0053      0.002     -2.459      0.014      -0.010      -0.001
# ============================================================================================
# """

# %% [markdown]
# # explore interactions with price

# %% [raw]
# To explore interactions between customization and price, we can introduce interaction terms between customization and std_price into the model. This will help us understand how the impact of customization may vary depending on the bid price.
#
# Steps:
# Introduce interaction terms: Create interaction terms between customization_prediction and std_price, and between customization_confidence and std_price.
# Fit the logistic regression model: Re-run the logistic regression to examine the impact of these interactions in high-competition settings.
# Analyze results: Focus on whether customization interacts with price to influence success.
# Let’s proceed with this analysis.
#
# The logistic regression model examining the interactions between customization and price in high-competition settings provides the following insights:
#
# Key Results:
# customization_prediction (个性化策略): Coefficient = -0.4080, p-value = 0.259. Customization alone does not have a significant impact on bid success.
#
# customization_confidence (个性化与自信的交互项): Coefficient = 0.3067, p-value = 0.480. The interaction between customization and confidence is not significant.
#
# customization_price (个性化与价格的交互项): Coefficient = 0.0001, p-value = 0.127. Although not significant, there is a slight positive trend indicating that customization may become more effective as the price increases.
#
# customization_confidence_price (个性化与自信及价格的交互项): Coefficient = -0.0009, p-value = 0.050. This interaction is marginally significant, suggesting that when customization is combined with confidence, it becomes less effective as the price increases.
#
# std_price (出价): Coefficient = -0.0001, p-value = 0.126. The price itself does not have a significant direct effect in this model.
#
# word (描述字数): Coefficient = -0.0051, p-value = 0.019. Shorter descriptions continue to have a significant positive effect on success.
#
# Summary:
# Customization alone does not significantly impact success in high-competition settings.
# The interaction between customization and price shows a slight, though not significant, positive trend.
# Customization combined with confidence and higher prices tends to have a marginally significant negative effect on success.
# Shorter bid descriptions remain a strong factor in successful bids in competitive environments.

# %%
# Create interaction terms between customization-related variables and price
high_competition_df['customization_price'] = high_competition_df['customization_prediction'] * high_competition_df['std_price']
high_competition_df['customization_confidence_price'] = high_competition_df['customization_confidence'] * high_competition_df['std_price']

# Define the independent variables focusing on customization, price, and their interactions
X_customization_price = high_competition_df[['customization_prediction', 'customization_confidence', 
                                             'customization_delivery', 'std_price', 'DDelivery', 'word',
                                             'customization_price', 'customization_confidence_price']]

# Define the dependent variable
y_customization_price = high_competition_df['std_award_status']

# Add a constant to the model
X_customization_price = sm.add_constant(X_customization_price)

# Fit the logistic regression model with interactions between customization and price
model_customization_price = sm.Logit(y_customization_price, X_customization_price)
result_customization_price = model_customization_price.fit()

# Display the summary of the customization-price interaction model
result_customization_price.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.023466
#          Iterations 15
# C:\Users\ergo_user\AppData\Local\Temp\ipykernel_13016\2050332040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_competition_df['customization_price'] = high_competition_df['customization_prediction'] * high_competition_df['std_price']
# C:\Users\ergo_user\AppData\Local\Temp\ipykernel_13016\2050332040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_competition_df['customization_confidence_price'] = high_competition_df['customization_confidence'] * high_competition_df['std_price']
# C:\Users\ergo_user\anaconda3\Lib\site-packages\statsmodels\discrete\discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\ergo_user\anaconda3\Lib\site-packages\statsmodels\discrete\discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                30626
# Model:                          Logit   Df Residuals:                    30617
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.02172
# Time:                        14:11:04   Log-Likelihood:                -718.67
# converged:                       True   LL-Null:                       -734.63
# Covariance Type:            nonrobust   LLR p-value:                 9.683e-05
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -4.8517      0.231    -21.032      0.000      -5.304      -4.400
# customization_prediction          -0.4080      0.362     -1.128      0.259      -1.117       0.301
# customization_confidence           0.3067      0.434      0.706      0.480      -0.545       1.158
# customization_delivery             0.0062      0.009      0.698      0.485      -0.011       0.024
# std_price                         -0.0001    6.6e-05     -1.529      0.126      -0.000    2.84e-05
# DDelivery                         -0.0020      0.008     -0.262      0.793      -0.017       0.013
# word                              -0.0051      0.002     -2.354      0.019      -0.009      -0.001
# customization_price                0.0001   6.63e-05      1.527      0.127   -2.87e-05       0.000
# customization_confidence_price    -0.0009      0.000     -1.956      0.050      -0.002    1.83e-06
# ==================================================================================================
# """

# %% [markdown]
# # How does price impact low competition

# %% [raw]
# To analyze how price impacts bid success in low-competition settings, we can isolate the low-competition group from the dataset and fit a logistic regression model. This will help us understand whether price has a different effect in environments where competition is lower.
#
# Steps:
# Isolate the low-competition group: Filter the data to only include the low-competition setting.
# Fit a logistic regression model: Focus on the impact of std_price and related variables (like customization, delivery time, etc.) in low-competition settings.
# Analyze results: Determine if price plays a more significant role when competition is less intense.
# Let’s proceed with this analysis.
#
# The logistic regression model for low-competition settings provides the following insights regarding the impact of price and other variables:
#
# Key Results:
# std_price (出价): Coefficient = -3.17e-08, p-value = 0.954. Price has no significant impact on bid success in low-competition settings, suggesting that pricing strategies are not critical when competition is low.
#
# customization_prediction (个性化策略): Coefficient = -0.0342, p-value = 0.871. Customization does not have a significant effect on success in low-competition environments.
#
# customization_confidence (个性化与自信的交互项): Coefficient = -0.6323, p-value = 0.005. This interaction has a significant negative effect, meaning that combining customization with confidence may actually reduce the chances of success in low-competition settings.
#
# customization_delivery (个性化与交付时间的交互项): Coefficient = 0.0174, p-value = 0.210. This interaction does not show a significant effect.
#
# DDelivery (交付时间): Coefficient = -0.0454, p-value < 0.001. Longer delivery times have a significant negative impact on success in low-competition environments.
#
# word (描述字数): Coefficient = -0.0052, p-value < 0.001. Shorter descriptions are more successful, similar to the high-competition setting.
#
# Summary for Low-Competition Settings:
# Price does not play a significant role in low-competition environments, which contrasts with high-competition settings where pricing can matter more.
# Customization combined with confidence significantly reduces success, indicating that this strategy may not be effective when competition is low.
# Shorter delivery times and concise descriptions continue to play a crucial role in success, even in low-competition environments.

# %%
# Filter data for low-competition settings
low_competition_df = df_full[df_full['competition_group'] == 'low_competition']

# Define the independent variables for low-competition settings
X_low_competition = low_competition_df[['customization_prediction', 'customization_confidence', 
                                        'customization_delivery', 'std_price', 'DDelivery', 'word']]

# Define the dependent variable
y_low_competition = low_competition_df['std_award_status']

# Add a constant to the model
X_low_competition = sm.add_constant(X_low_competition)

# Fit the logistic regression model for low-competition data
model_low_competition = sm.Logit(y_low_competition, X_low_competition)
result_low_competition = model_low_competition.fit()

# Display the summary of the low-competition model
result_low_competition.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.075866
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       std_award_status   No. Observations:                31503
# Model:                          Logit   Df Residuals:                    31496
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.02498
# Time:                        14:15:02   Log-Likelihood:                -2390.0
# converged:                       True   LL-Null:                       -2451.3
# Covariance Type:            nonrobust   LLR p-value:                 4.955e-24
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -3.2741      0.105    -31.113      0.000      -3.480      -3.068
# customization_prediction    -0.0342      0.211     -0.163      0.871      -0.447       0.379
# customization_confidence    -0.6323      0.226     -2.798      0.005      -1.075      -0.189
# customization_delivery       0.0174      0.014      1.253      0.210      -0.010       0.045
# std_price                 -3.17e-08   5.53e-07     -0.057      0.954   -1.12e-06    1.05e-06
# DDelivery                   -0.0454      0.008     -5.530      0.000      -0.062      -0.029
# word                        -0.0052      0.001     -4.758      0.000      -0.007      -0.003
# ============================================================================================
# """

# %% [markdown]
# # 重新定义高竞争和低竞争

# %% [raw]
# To explore how customization works in both high-competition and low-competition settings based on the new classification, we can analyze the following:
#
# High-competition setting: Focus on how customization and its interactions (e.g., with price, delivery time) influence success in high-competition environments.
# Low-competition setting: Similarly, examine how customization performs in low-competition environments.
# Steps:
# We'll fit separate logistic regression models for high-competition and low-competition settings, focusing on customization and related interaction terms.
# We'll compare the results to understand how customization's effectiveness differs between these two environments.
# Let’s begin with this analysis.
#
# Here are the results for customization in both high-competition and low-competition settings, based on the new classification:
#
# 1. High-Competition Setting:
# customization_prediction: Coefficient = -0.0221, p-value = 0.969. Customization does not have a significant effect on bid success in high-competition settings.
# customization_confidence: Coefficient = -0.9252, p-value = 0.097. This interaction shows a negative effect, approaching significance (p < 0.1), suggesting that combining customization with confidence may not be advantageous in high-competition environments.
# customization_delivery: Coefficient = 0.0300, p-value = 0.094. There is a marginal positive effect, indicating that customization might work better when paired with shorter delivery times.
# 2. Low-Competition Setting:
# customization_prediction: Coefficient = -0.0398, p-value = 0.843. Customization does not significantly affect bid success in low-competition settings either.
# customization_confidence: Coefficient = -0.5232, p-value = 0.013. This interaction is significant, with a negative effect, indicating that combining customization with confidence reduces the likelihood of success in low-competition environments.
# customization_delivery: Coefficient = 0.0014, p-value = 0.911. The interaction between customization and delivery time has no significant effect.
# Other Variables:
# In both settings, shorter delivery times (negative coefficient for DDelivery) and concise descriptions (word) have significant positive effects on success.
# Price does not have a significant effect in either high-competition or low-competition settings.
# Summary:
# Customization alone does not significantly impact success in either high- or low-competition settings.
# Customization combined with confidence tends to have a negative effect in both settings, especially in low-competition environments.
# Customization paired with shorter delivery times might be more effective in high-competition environments, though this effect is only marginally significant.

# %%
# Recalculate high and low competition based on the 75th percentile of the 'competition' variable
value_75_percentile = df_full['competition'].quantile(0.75)

# Reassign high and low competition groups based on the 75th percentile
df_full['competition_group_new'] = df_full['competition'].apply(lambda x: 'high_competition' if x > value_75_percentile else 'low_competition')

# Display the distribution of the new competition group classification
df_full['competition_group_new'].value_counts()
# Out:
# competition_group_new
# low_competition     46643
# high_competition    15486
# Name: count, dtype: int64

# %%
# Filter data for the new high-competition and low-competition settings
high_competition_new_df = df_full[df_full['competition_group_new'] == 'high_competition']
low_competition_new_df = df_full[df_full['competition_group_new'] == 'low_competition']

# Define the independent variables focusing on customization and control variables for both groups
X_high_customization = high_competition_new_df[['scaled_price', 'confidence_prediction','politeness_prediction',
                  'customization_prediction','skill_prediction', 
                  'customization_confidence' ,'customization_politeness','customization_skill',
                 
                  'DDelivery', 
                  'word']]
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_high_customization.columns
vif_data['VIF'] = [variance_inflation_factor(X_high_customization.values, i) for i in range(X_high_customization.shape[1])]
# 显示 VIF
print(vif_data)

X_low_customization = low_competition_new_df[['scaled_price', 'confidence_prediction','politeness_prediction',
                  'customization_prediction','skill_prediction', 
                  'customization_confidence' ,'customization_politeness','customization_skill',
                 
                  'DDelivery', 
                  'word']]
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = X_low_customization.columns
vif_data['VIF'] = [variance_inflation_factor(X_low_customization.values, i) for i in range(X_low_customization.shape[1])]
# 显示 VIF
print(vif_data)
# Define the dependent variable
y_high_customization = high_competition_new_df['std_award_status']
y_low_customization = low_competition_new_df['std_award_status']

# Add a constant to the models
X_high_customization = sm.add_constant(X_high_customization)
X_low_customization = sm.add_constant(X_low_customization)

# Fit logistic regression models for high and low competition data
model_high_customization = sm.Logit(y_high_customization, X_high_customization)
result_high_customization = model_high_customization.fit()

model_low_customization = sm.Logit(y_low_customization, X_low_customization)
result_low_customization = model_low_customization.fit()

# Display the summaries of both models
high_competition_summary = result_high_customization.summary()
low_competition_summary = result_low_customization.summary()

high_competition_summary, low_competition_summary
# Out:
#                    Variable       VIF
# 0              scaled_price  1.057927
# 1     confidence_prediction  5.026022
# 2     politeness_prediction  3.631852
# 3  customization_prediction  8.898296
# 4          skill_prediction  4.150018
# 5  customization_confidence  5.002559
# 6  customization_politeness  5.312424
# 7       customization_skill  4.053584
# 8                 DDelivery  1.223460
# 9                      word  6.297591
#                    Variable       VIF
# 0              scaled_price  1.006479
# 1     confidence_prediction  4.052643
# 2     politeness_prediction  3.087660
# 3  customization_prediction  8.835631
# 4          skill_prediction  3.407412
# 5  customization_confidence  4.288558
# 6  customization_politeness  5.111637
# 7       customization_skill  3.480577
# 8                 DDelivery  1.636293
# 9                      word  5.622995
# Optimization terminated successfully.
#          Current function value: 0.016926
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.061780
#          Iterations 10
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                15486
#  Model:                          Logit   Df Residuals:                    15475
#  Method:                           MLE   Df Model:                           10
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.01582
#  Time:                        20:13:34   Log-Likelihood:                -262.12
#  converged:                       True   LL-Null:                       -266.34
#  Covariance Type:            nonrobust   LLR p-value:                    0.5870
#  ============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
#  --------------------------------------------------------------------------------------------
#  const                       -5.9939      0.618     -9.702      0.000      -7.205      -4.783
#  scaled_price             -4.225e-05      0.001     -0.058      0.954      -0.001       0.001
#  confidence_prediction        0.4693      0.497      0.944      0.345      -0.505       1.444
#  politeness_prediction       -0.3746      0.422     -0.887      0.375      -1.203       0.453
#  customization_prediction     1.4663      0.839      1.747      0.081      -0.179       3.112
#  skill_prediction             0.4382      0.499      0.878      0.380      -0.539       1.416
#  customization_confidence    -1.3510      0.738     -1.830      0.067      -2.798       0.096
#  customization_politeness    -0.1145      0.712     -0.161      0.872      -1.510       1.281
#  customization_skill         -0.6406      0.750     -0.854      0.393      -2.110       0.829
#  DDelivery                   -0.0018      0.008     -0.224      0.823      -0.018       0.014
#  word                        -0.0041      0.004     -1.057      0.291      -0.012       0.003
#  ============================================================================================
#  """,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                             Logit Regression Results
#  ==============================================================================
#  Dep. Variable:       std_award_status   No. Observations:                46643
#  Model:                          Logit   Df Residuals:                    46632
#  Method:                           MLE   Df Model:                           10
#  Date:                Tue, 24 Sep 2024   Pseudo R-squ.:                 0.02870
#  Time:                        20:13:34   Log-Likelihood:                -2881.6
#  converged:                       True   LL-Null:                       -2966.8
#  Covariance Type:            nonrobust   LLR p-value:                 2.391e-31
#  ============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
#  --------------------------------------------------------------------------------------------
#  const                       -3.3998      0.117    -29.111      0.000      -3.629      -3.171
#  scaled_price              4.641e-06   1.85e-06      2.514      0.012    1.02e-06    8.26e-06
#  confidence_prediction        0.0162      0.104      0.156      0.876      -0.188       0.221
#  politeness_prediction       -0.0127      0.102     -0.125      0.901      -0.212       0.187
#  customization_prediction    -0.0932      0.276     -0.337      0.736      -0.635       0.449
#  skill_prediction            -0.2164      0.102     -2.112      0.035      -0.417      -0.016
#  customization_confidence    -0.6529      0.233     -2.797      0.005      -1.110      -0.195
#  customization_politeness    -0.3201      0.247     -1.294      0.196      -0.805       0.165
#  customization_skill          0.6260      0.242      2.590      0.010       0.152       1.100
#  DDelivery                   -0.0339      0.005     -6.332      0.000      -0.044      -0.023
#  word                        -0.0056      0.001     -4.855      0.000      -0.008      -0.003
#  ============================================================================================
#  """)

# %% [markdown]
# # 之前的主模型

# %% [markdown]
# ## 放入控制变量

# %%
import statsmodels.api as sm

# Selecting the variables for the regression analysis
dependent_variable = df['std_award_status']
independent_variables = df[['std_price', 'competition', 'confidence_prediction', 'skill_prediction',
                            'standardization_prediction', 'experience_prediction', 
                            'politeness_prediction', 'customization_prediction', 
                            'word', 'time_diff', 'DDelivery']]

# Adding a constant to the independent variables (for the intercept in the regression model)
independent_variables = sm.add_constant(independent_variables)

# Fitting the regression model
model = sm.OLS(dependent_variable, independent_variables).fit()

# Displaying the summary of the regression analysis
regression_summary = model.summary()
regression_summary

# %% [markdown]
# ## 不放入控制变量

# %%
# Selecting the variables for the regression analysis
dependent_variable = df['std_award_status']
independent_variables = df[['std_price', 'competition', 'confidence_prediction', 'skill_prediction',
                            'standardization_prediction', 'experience_prediction', 
                            'politeness_prediction', 'customization_prediction']]

# Adding a constant to the independent variables (for the intercept in the regression model)
independent_variables = sm.add_constant(independent_variables)

# Fitting the regression model
model = sm.OLS(dependent_variable, independent_variables).fit()

# Displaying the summary of the regression analysis
regression_summary = model.summary()
regression_summary

# %% [raw]
# 重新划分一下高竞争和低竞争。比如用这种方法：value_75_percentile = df['competition'].quantile(0.75)，大于数据分布75%的算作高竞争

# %% [markdown]
# ## 创建高竞争、低竞争

# %%
# Defining competition_median as the median of the competition column, which represents the middle value of the distribution
competition_median = df['competition'].mean()
value_75_percentile = df['competition'].quantile(0.75)
value_25_percentile = df['competition'].quantile(0.25)

# Re-create the high_competition variable using this definition
df['high_competition'] = df['competition'].apply(lambda x: 1 if x > value_75_percentile else 0)
df['low_competition'] = df['competition'].apply(lambda x: 1 if x < value_25_percentile else 0)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Re-run the regression model with the updated high_competition variable
independent_variables = df[['std_price', 'confidence_prediction', 'skill_prediction',
                            'experience_prediction', 
                            'politeness_prediction', 'customization_prediction', 
                            'word', 'time_diff', 'DDelivery', 'high_competition']]
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = independent_variables.columns
vif_data['VIF'] = [variance_inflation_factor(independent_variables.values, i) for i in range(independent_variables.shape[1])]

# 显示 VIF
print(vif_data)
# Adding a constant for the intercept
independent_variables = sm.add_constant(independent_variables)

# Fitting the new regression model
model_with_updated_competition = sm.OLS(dependent_variable, independent_variables).fit()

# Displaying the summary of the regression analysis
model_with_updated_competition_summary = model_with_updated_competition.summary()
model_with_updated_competition_summary

# %%
# Filtering the data for high competition projects only (high_competition = 1)
high_competition_data = df[df['high_competition'] == 1]

# Selecting the independent variables for this subset
independent_variables_high_competition = high_competition_data[['std_price', 'skill_prediction',
                                                               
                                                                'customization_prediction', 
                                                                ]]
# 计算 VIF
vif_data = pd.DataFrame()
vif_data['Variable'] = independent_variables_high_competition.columns
vif_data['VIF'] = [variance_inflation_factor(independent_variables_high_competition.values, i) for i in range(independent_variables_high_competition.shape[1])]

# 显示 VIF
print(vif_data)

# Adding a constant for the intercept
independent_variables_high_competition = sm.add_constant(independent_variables_high_competition)

# Defining the dependent variable for this subset
dependent_variable_high_competition = high_competition_data['std_award_status']

# Fitting the regression model for high competition data only
model_high_competition_subset = sm.OLS(dependent_variable_high_competition, independent_variables_high_competition).fit()

# Displaying the summary of the regression analysis
model_high_competition_subset_summary = model_high_competition_subset.summary()
model_high_competition_subset_summary

# %%
# Filtering the data for high competition projects only (high_competition = 1)
high_competition_data = df[df['high_competition'] == 1]

# Selecting the independent variables for this subset
independent_variables_high_competition = high_competition_data[['std_price',
                                                                'standardization_prediction',  'customization_prediction', 
                                                                'word', 'time_diff', 'DDelivery']]

# Adding a constant for the intercept
independent_variables_high_competition = sm.add_constant(independent_variables_high_competition)

# Defining the dependent variable for this subset
dependent_variable_high_competition = high_competition_data['std_award_status']

# Fitting the regression model for high competition data only
model_high_competition_subset = sm.OLS(dependent_variable_high_competition, independent_variables_high_competition).fit()

# Displaying the summary of the regression analysis
model_high_competition_subset_summary = model_high_competition_subset.summary()
model_high_competition_subset_summary

# %%
# Filtering the data for high competition projects only (high_competition = 1)
high_competition_data = df[df['low_competition'] == 1]

# Selecting the independent variables for this subset
independent_variables_high_competition = high_competition_data[['std_price',
                                                                'standardization_prediction',  'customization_prediction', 
                                                                'word', 'time_diff', 'DDelivery']]

# Adding a constant for the intercept
independent_variables_high_competition = sm.add_constant(independent_variables_high_competition)

# Defining the dependent variable for this subset
dependent_variable_high_competition = high_competition_data['std_award_status']

# Fitting the regression model for high competition data only
model_high_competition_subset = sm.OLS(dependent_variable_high_competition, independent_variables_high_competition).fit()

# Displaying the summary of the regression analysis
model_high_competition_subset_summary = model_high_competition_subset.summary()
model_high_competition_subset_summary
